# %%
import pandas as pd

# %%
# Carrega o arquivo
# diz ao Python para ignorar qualquer caractere de escape e ler o texto exatamente como ele é:
df = pd.read_excel(r'D:\Documentos\TTTrabalhos\InfNET\ProjetoBL06\Databases\excel_Cliente.xlsx')
# No Jupyter, basta colocar o nome da variável na última linha para exibir a tabela
df

# %%
# O Windows e o Python aceitam barras para a direita (/), que não causam conflitos:
df1 = pd.read_excel('D:/Documentos/TTTrabalhos/InfNET/ProjetoBL06/Databases/excel_Cliente.xlsx')
df1

# %%
# Você "anula" o efeito da barra invertida usando duas:
df2 = pd.read_excel('D:\\Documentos\\TTTrabalhos\\InfNET\\ProjetoBL06\\Databases\\excel_Cliente.xlsx')
df2

# %%
df3 = pd.read_excel(r'D:\Documentos\TTTrabalhos\InfNET\ProjetoBL06\Databases\excel_Cliente.xlsx', sheet_name='sheet1')
df3

# %%
nome_arquivo = r'D:\Documentos\TTTrabalhos\InfNET\ProjetoBL06\Databases\excel_Cliente.xlsx'

# Carrega o Excel
df4 = pd.read_excel(nome_arquivo)

# Percorrendo linha a linha para enviar ao banco
for indice, linha in df.iterrows():
    # Acessando os dados pelas colunas (Troque pelos nomes REAIS do seu Excel)
    nome_cliente = linha['Nome']
    email_cliente = linha['Email']
    telefone = linha['Telefone']
    
    # Aqui entraria o seu comando de INSERT do SQL
    print(f"Processando linha {indice}: Gravando {nome_cliente} no banco...")
    
    # Exemplo de como você montaria a lógica:
    # cursor.execute("INSERT INTO clientes (nome, email) VALUES (?, ?)", (nome_cliente, email_cliente))

print("\n--- Carga finalizada com sucesso! ---")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 df4 = pd.read_excel(nome_arquivo)
#       6 # Percorrendo linha a linha para enviar ao banco
# ----> 7 for indice, linha in df.iterrows():
#       8     # Acessando os dados pelas colunas (Troque pelos nomes REAIS do seu Excel)
#       9     nome_cliente = linha['Nome']
#      10     email_cliente = linha['Email']
#
# NameError: name 'df' is not defined

# %%
df.info()

# %%
df.head(5)
