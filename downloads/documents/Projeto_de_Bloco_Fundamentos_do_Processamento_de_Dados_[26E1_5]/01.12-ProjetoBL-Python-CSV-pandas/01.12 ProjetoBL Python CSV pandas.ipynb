# %%
import pandas as pd
import csv

# %%
# Carrega o arquivo
# diz ao Python para ignorar qualquer caractere de escape e ler o texto exatamente como ele é:
df = pd.read_csv(r'D:\Documentos\TTTrabalhos\InfNET\ProjetoBL06\Databases\csv_Cliente.csv')
# No Jupyter, basta colocar o nome da variável na última linha para exibir a tabela
df

# %%
# O Windows e o Python aceitam barras para a direita (/), que não causam conflitos:
df1 = pd.read_csv('D:/Documentos/TTTrabalhos/InfNET/ProjetoBL06/Databases/csv_Cliente.csv')
df1

# %%
# Você "anula" o efeito da barra invertida usando duas:
df2 = pd.read_csv('D:\\Documentos\\TTTrabalhos\\InfNET\\ProjetoBL06\\Databases\\csv_Cliente.csv')
df2

# %%
df.head(5)

# %%
df.info()

# %%
# Nome do seu arquivo CSV
nome_arquivo = r'D:\Documentos\TTTrabalhos\InfNET\ProjetoBL06\Databases\csv_Cliente.csv'

# Abre o arquivo CSV para leitura
with open(nome_arquivo, mode='r', encoding='utf-8') as arquivo:
    # Cria um objeto leitor
    leitor = csv.reader(arquivo)

    # Itera sobre cada linha do arquivo
    for linha in leitor:
        # Exibe a linha na tela do MU
        print(linha)
